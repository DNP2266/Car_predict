# %% [markdown]
# # Dự đoán giá xe ô tô (Regression)
#
# Bài toán: dự đoán biến mục tiêu `Price`.
#
# Quy trình: EDA → Tiền xử lý → Huấn luyện ≥3 mô hình → Đánh giá → Lưu kết quả vào `outputs/`

# %% [markdown]
# ## Bước 1. Khám phá dữ liệu (EDA)
#
# - Đọc `data/train.csv`
# - Thống kê mô tả, missing, trùng lặp
# - Vẽ phân phối `Price`, heatmap tương quan
# - Lưu hình vào `outputs/figures/`

# %%
import pandas as pd
import matplotlib

# %%
train_data = pd.read_csv('data/train.csv')

# %% [markdown]
# ## Bước 2. Tiền xử lý dữ liệu
#
# - Xử lý missing, outlier, encode biến phân loại, scale
# - Tách `X`, `y`; chia train/test (ví dụ 80/20, `random_state=42`)
# - Không fit scaler trên tập test

# %% [markdown]
# ## Bước 3. Huấn luyện mô hình
#
# Huấn luyện **ít nhất 3** mô hình regression trên cùng tập train, ví dụ:
#
# - Linear Regression
# - Decision Tree Regressor
# - Random Forest Regressor
# - KNN Regressor

# %% [markdown]
# ## Bước 4. Đánh giá mô hình
#
# - Tính MAE, MSE, RMSE, R² trên cùng tập test
# - Vẽ Actual vs Predicted, residual (khuyến khích)
# - Lưu bảng kết quả vào `outputs/results.csv`

# %% [markdown]
# ## Bước 5. So sánh và kết luận
#
# - So sánh các mô hình, chọn mô hình tốt nhất
# - Điền nhận xét vào `report.md`

# %%
# Viết code tại đây
# import pandas as pd
# df = pd.read_csv("data/train.csv")
